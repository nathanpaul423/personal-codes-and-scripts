# %%
import pandas as pd

# %%
pip install openpyxl
# Out:
# [notice] A new release of pip available: 22.2.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
df = pd.read_excel(r'C:\Users\NATHANPAULBUSTAMANTE\OneDrive\Desktop\Personality test\ADAPT\sample analysis for python.xlsx')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 183 entries, 0 to 182
# Data columns (total 85 columns):
#  #   Column                                                                                                                                                                                                       Non-Null Count  Dtype
# ---  ------                                                                                                                                                                                                       --------------  -----
#  0   Response ID                                                                                                                                                                                                  183 non-null    int64
# ...

# %%
df
# Out:
#      Response ID                   Industry  \
# 0             79                  Retailing
# 1             80                 Government
# 2             81                  Education
# 3             82                 Financials
# 4             83  Industrials/Manufacturing
# ..           ...                        ...
# 178          283  Airlines & Transportation
# 179          285                Health Care
# 180          286                Health Care
# 181          287  Airlines & Transportation
# 182          288                  Utilities
#
#                                 Org Size  Employee Size      Revenue  \
# 0       Enterprise (2501 to 10,000 emp.)           3500   2798400000
# 1          Mid-market (501 to 2500 emp.)           1263    577879000
# 2       Enterprise (2501 to 10,000 emp.)           2934    752002000
# 3    Small/medium corporate (1-500 emp.)            351    635181000
# 4       Enterprise (2501 to 10,000 emp.)           6737  18435100000
# ...

# %%
numeric_columns = df.select_dtypes(include=['number'])

# %%
numeric_columns.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 183 entries, 0 to 182
# Data columns (total 38 columns):
#  #   Column                                                                                                                  Non-Null Count  Dtype
# ---  ------                                                                                                                  --------------  -----
#  0   Response ID                                                                                                             183 non-null    int64
#  1   Employee Size                                                                                                           183 non-null    int64
#  2   Revenue                                                                                                                 183 non-null    int64
# ...

# %%
numeric_columns.columns
# Out:
# Index(['Response ID', 'Employee Size', 'Revenue', 'Modernised IT activities',
#        'Connected Business activities', 'Exponential Enterprise activities',
#        'Outside of your traditional sector', 'Innovation', 'Cross-selling',
#        'Digital channels', 'Ecosystems and platforms',
#        'Please indicate the approximate IT budget for the current financial year.',
#        ' back-office applications (for example, ERP) ',
#        ' customer applications and portals ',
#        ' digital workplace (devices, productivity tools and processes) ',
#        ' infrastructure (in-house and in hybrid, multi-cloud) ',
#        ' innovation (research and development) ',
#        ' IT services (outsourcing, project management, staff augmentation, consulting) ',
#        ' people (operational, upskilling, awareness and other) ',
#        ' remediation of systems, environments and processes ', ' security ',
#        ' other ',
# ...

# %%
#drop NA's
features = ['Employee Size', 'Revenue','Please indicate the approximate IT budget for the current financial year.','Executive leadership team (C-suite) is â€˜digitally savvy','Employees that are â€˜digitally fitâ€™']

# %%
data = df.dropna(subset=features)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [21], in <cell line: 1>()
# ----> 1 data = df.dropna(subset=features)
#
# File c:\Users\NATHANPAULBUSTAMANTE\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File c:\Users\NATHANPAULBUSTAMANTE\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:6008, in DataFrame.dropna(self, axis, how, thresh, subset, inplace)
#    6006     check = indices == -1
#    6007     if check.any():
# ...
